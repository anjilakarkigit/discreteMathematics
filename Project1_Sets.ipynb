# %% [markdown]
# <a href="https://colab.research.google.com/github/anjilakarkigit/discreteMathematics/blob/main/Project1_Sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part #1 : CPSMA 3133 [Dr. Jacob's](https://github.com/nurfnick) Discrete Mathematics
#
# ## Sets
#
# ### Anjila Karki, 267815

# %% [markdown]
# I am going to have keto diet theme to my this assignment.

# %% [markdown]
# Set A will be the foods that fall under protein. Set B will be the foods that fall under fats and set C will be the foods that are green veggies.

# %% [markdown]
# ![A-ketogenic-diet.png](data:image/png;base64,...)

# %%
#the {} actually define these as sets in python. [] define these as lists
protein = {'bacon', 'egg', 'mutton', 'chicken', 'peanuts', 'almonds', 'turkey', 'beef',  'string cheese', 'salmon', 'Peanut Butter', 
           'yoghurt','edamame','asparagus','broccoli'}
fats = {'avocado', 'egg', 'salmon', 'almonds', 'peanuts', 'olives','tofu', 'yoghurt', 'Peanut Butter','string cheese','shrimp','tuna'}
veggies = {'lettuce','spinach','mustrad greens', 'asparagus', 'edamame','broccoli','avocado','wheatgrass', 'celery'}

# %% [markdown]
# My universal set U  would be all the foods that are keto friendly.

# %% [markdown]
# Now I will be using pythonic structure for dealing with sets. After doing the union of two sets, I noticed that the result will contain element
#  from both the sets and keep them in alphabetical order.

# %%
protein.union(fats)
# Out:
# {'Peanut Butter',
#  'almonds',
#  'asparagus',
#  'avocado',
#  'bacon',
#  'beef',
#  'broccoli',
#  'chicken',
#  'edamame',
#  'egg',
#  'mutton',
#  'olives',
#  'peanuts',
#  'salmon',
#  'shrimp',
#  'string cheese',
#  'tofu',
#  'tuna',
#  'turkey',
#  'yoghurt'}

# %%
protein.union(veggies)
# Out:
# {'Peanut Butter',
#  'almonds',
#  'asparagus',
#  'avocado',
#  'bacon',
#  'beef',
#  'broccoli',
#  'celery',
#  'chicken',
#  'edamame',
#  'egg',
#  'lettuce',
#  'mustrad greens',
#  'mutton',
#  'peanuts',
#  'salmon',
#  'spinach',
#  'string cheese',
#  'turkey',
#  'wheatgrass',
#  'yoghurt'}

# %%
fats.union(veggies)
# Out:
# {'Peanut Butter',
#  'almonds',
#  'asparagus',
#  'avocado',
#  'broccoli',
#  'celery',
#  'edamame',
#  'egg',
#  'lettuce',
#  'mustrad greens',
#  'olives',
#  'peanuts',
#  'salmon',
#  'shrimp',
#  'spinach',
#  'string cheese',
#  'tofu',
#  'tuna',
#  'wheatgrass',
#  'yoghurt'}

# %% [markdown]
# Now I will be doing the intersection of the sets in similar fashion.

# %%
protein.intersection(fats)
# Out:
# {'Peanut Butter',
#  'almonds',
#  'egg',
#  'peanuts',
#  'salmon',
#  'string cheese',
#  'yoghurt'}

# %%
protein.intersection(veggies)
# Out:
# {'asparagus', 'broccoli', 'edamame'}

# %%
fats.intersection(veggies)
# Out:
# {'avocado'}

# %% [markdown]
# Doing the intersection and union of two sets, I noticed that there is no difference which set will be called first because the result will be the same
# regardless.

# %% [markdown]
# Here, I am going to create a loop in here to develop the universal set.

# %%
SetofSets = [protein,fats,veggies]
U = set() #you have to initialize a set as set() not {}, python thinks the later is a dictionary Module2.
for everySet in SetofSets:
  U = U.union(everySet)

U
# Out:
# {'Peanut Butter',
#  'almonds',
#  'asparagus',
#  'avocado',
#  'bacon',
#  'beef',
#  'broccoli',
#  'celery',
#  'chicken',
#  'edamame',
#  'egg',
#  'lettuce',
#  'mustrad greens',
#  'mutton',
#  'olives',
#  'peanuts',
#  'salmon',
#  'shrimp',
#  'spinach',
#  'string cheese',
#  'tofu',
#  'tuna',
#  'turkey',
#  'wheatgrass',
#  'yoghurt'}

# %%
Now I am going to find out the complement of each sets.

# %%
U - protein
# Out:
# {'avocado',
#  'celery',
#  'lettuce',
#  'mustrad greens',
#  'olives',
#  'shrimp',
#  'spinach',
#  'tofu',
#  'tuna',
#  'wheatgrass'}

# %%
U - fats
# Out:
# {'asparagus',
#  'bacon',
#  'beef',
#  'broccoli',
#  'celery',
#  'chicken',
#  'edamame',
#  'lettuce',
#  'mustrad greens',
#  'mutton',
#  'spinach',
#  'turkey',
#  'wheatgrass'}

# %%
U - veggies
# Out:
# {'Peanut Butter',
#  'almonds',
#  'bacon',
#  'beef',
#  'chicken',
#  'egg',
#  'mutton',
#  'olives',
#  'peanuts',
#  'salmon',
#  'shrimp',
#  'string cheese',
#  'tofu',
#  'tuna',
#  'turkey',
#  'yoghurt'}

# %% [markdown]
# Now, I am going to find out the complement of protein union veggies because I felt like most of the elements came under their union. I wanted to find out the remaining ones and after the calculation, I got only four elements as a result.

# %%
U - protein.union(veggies)
# Out:
# {'olives', 'shrimp', 'tofu', 'tuna'}

# %%
None of the sets are subsets here because those sets do not have all elements exactly similar to the elements of other sets.

# %%
Here, I am going to compute a power set for set A.
